# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import librosa
from IPython.display import Audio
from typing import Union, Callable, Tuple
from pathlib import Path

from week1code import get_mic_samples, get_spec, get_mp3_samples
from spectragram import transcribe_audio

# %%
transcribe_audio(20)
# Out:
# Using input device 'Built-in Microphone'
# Recording ended
# 355.27550166288563
# I am at display_notes
# play [] for 0.9 seconds.
# play [] for 0.9 seconds.
# play ['D4', 'D4', 'D5', 'C#/Db4'] for 1.9 seconds.
# play ['B5', 'E4', 'E4', 'B5'] for 0.9 seconds.
# play ['F#/Gb4', 'A#/Bb6', 'F#/Gb4', 'F#/Gb6'] for 1.9 seconds.
# play ['B6', 'B6', 'Overtone', 'G5'] for 0.9 seconds.
# play ['G6', 'G6', 'B6', 'G5'] for 0.9 seconds.
# play ['A4', 'A4', 'Overtone', 'Overtone'] for 0.9 seconds.
# play ['B5', 'B6', 'A#/Bb5', 'A#/Bb6'] for 0.9 seconds.
# play ['B6', 'B4', 'B6', 'Overtone'] for 0.9 seconds.
# play ['C#/Db5', 'C#/Db5', 'Overtone', 'Overtone'] for 1.9 seconds.
# play ['A6', 'A6', 'A6', 'Overtone'] for 0.9 seconds.
# play ['D5', 'D5', 'A6', 'A6'] for 0.9 seconds.
# play ['C#/Db6', 'C#/Db5', 'Overtone', 'C#/Db6'] for 0.9 seconds.
# play ['B6', 'B6', 'B4', 'B6'] for 1.9 seconds.
# play ['A4', 'A4', 'Overtone', 'Overtone'] for 1.9 seconds.
# play ['B6', 'B6', 'Overtone', 'Overtone'] for 0.4 seconds.

# %%
def ecdf(data):
    """Returns (x) the sorted data and (y) the empirical cumulative-proportion
    of each datum.
    
    Parameters
    ----------
    data : numpy.ndarray, size-N
    
    Returns
    -------
    Tuple[numpy.ndarray shape-(N,), numpy.ndarray shape-(N,)]
        Sorted data, empirical CDF values"""
    data = np.asarray(data).ravel()
    y = np.linspace(1 / len(data), 1, len(data))
    x = np.sort(data)
    return x, y
